# %% [markdown]
# #### 9. This exercise involves the `Auto` data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-dark.mplstyle")

# %%
auto: pd.DataFrame = pd.read_csv("../../Auto.csv")

# %%
quantitative_predictors: list[str] = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "year"
]
qualitative_predictors = ["origin", "name"]

# %%
auto[quantitative_predictors].describe().loc[["min", "max"]].T
# pd.DataFrame({"min": auto[quantitative_predictors].min(), "max": auto[quantitative_predictors].max()})
# Out:
#                  min     max
# mpg              9.0    46.6
# cylinders        3.0     8.0
# displacement    68.0   455.0
# horsepower      46.0   230.0
# weight        1613.0  5140.0
# acceleration     8.0    24.8
# year            70.0    82.0

# %%
auto[quantitative_predictors].describe().loc[["mean", "std"]]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# mean  23.445918   5.471939    194.411990  104.469388  2977.584184
# std    7.805007   1.705783    104.644004   38.491160   849.402560
#
#       acceleration       year
# mean     15.541327  75.979592
# std       2.758864   3.683737

# %%
subset = auto.iloc[[x for x in range(len(auto)) if not(10 <= x <= 85)]]
subset.describe().loc[["min", "max", "mean", "std"]]
# Out:
#             mpg  cylinders  displacement  horsepower      weight  \
# min   11.000000   3.000000     68.000000   46.000000  1649.00000
# max   46.600000   8.000000    455.000000  230.000000  4997.00000
# mean  24.407595   5.373418    187.512658  100.848101  2936.53481
# std    7.863285   1.654179    100.114616   35.954147   811.87445
#
#       acceleration       year    origin
# min       8.500000  70.000000  1.000000
# max      24.800000  82.000000  3.000000
# mean     15.717405  77.136076  1.601266
# std       2.713876   3.123464  0.819910

# %%
# Can see that mpg has non-linear decrease with displacement, horsepower and weight;
# displacement, horsepower and weight are positively linearly correlated to each other 
pd.plotting.scatter_matrix(auto[quantitative_predictors], figsize=(12, 12));

# %%
import numpy as np
